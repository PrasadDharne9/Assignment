# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
A = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Bike Rental Project/hour.csv")

# %%
A
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 0            1  2011-01-01       1   0     1   0        0        6
# 1            2  2011-01-01       1   0     1   1        0        6
# 2            3  2011-01-01       1   0     1   2        0        6
# 3            4  2011-01-01       1   0     1   3        0        6
# 4            5  2011-01-01       1   0     1   4        0        6
# ...        ...         ...     ...  ..   ...  ..      ...      ...
# 17374    17375  2012-12-31       1   1    12  19        0        1
# 17375    17376  2012-12-31       1   1    12  20        0        1
# 17376    17377  2012-12-31       1   1    12  21        0        1
# 17377    17378  2012-12-31       1   1    12  22        0        1
# 17378    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 0               0           1  0.24  0.2879  0.81     0.0000       3
# ...

# %%
B = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Bike Rental Project/hour.csv")

# %%
B = B.iloc[:1000,:]

# %%
B
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1   0        0        6           0
# 1          2  2011-01-01       1   0     1   1        0        6           0
# 2          3  2011-01-01       1   0     1   2        0        6           0
# 3          4  2011-01-01       1   0     1   3        0        6           0
# 4          5  2011-01-01       1   0     1   4        0        6           0
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 995      996  2011-02-14       1   0     2   3        0        1           1
# 996      997  2011-02-14       1   0     2   4        0        1           1
# 997      998  2011-02-14       1   0     2   5        0        1           1
# 998      999  2011-02-14       1   0     2   6        0        1           1
# 999     1000  2011-02-14       1   0     2   7        0        1           1
#
# ...

# %%
B
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1   0        0        6           0
# 1          2  2011-01-01       1   0     1   1        0        6           0
# 2          3  2011-01-01       1   0     1   2        0        6           0
# 3          4  2011-01-01       1   0     1   3        0        6           0
# 4          5  2011-01-01       1   0     1   4        0        6           0
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 995      996  2011-02-14       1   0     2   3        0        1           1
# 996      997  2011-02-14       1   0     2   4        0        1           1
# 997      998  2011-02-14       1   0     2   5        0        1           1
# 998      999  2011-02-14       1   0     2   6        0        1           1
# 999     1000  2011-02-14       1   0     2   7        0        1           1
#
# ...

# %%
A.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
B.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %% [markdown]
# ## Checking Whether two dataset are having the same variables

# %%
C = B.columns.intersection(A.columns)

# %%
if len(A.columns)==len(B.columns.intersection(A.columns)):
  print("The Datasets have Same Variables")
else:
  print("The Datasets have different Variables")
# Out:
# The Datasets have Same Variables
